# %%
# %load_ext tensorboard

# %%
import torch
import torchvision
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms

# Writer will output to ./runs/ directory by default
writer = SummaryWriter()

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
trainset = datasets.MNIST('mnist_train', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
model = torchvision.models.resnet50(False)
# Have ResNet model take in grayscale rather than RGB
model.conv1 = torch.nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
images, labels = next(iter(trainloader))

grid = torchvision.utils.make_grid(images)
writer.add_image('images', grid, 0)
writer.add_graph(model, images)
writer.close()
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to mnist_train/MNIST/raw/train-images-idx3-ubyte.gz
# 100.1%
# Extracting mnist_train/MNIST/raw/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to mnist_train/MNIST/raw/train-labels-idx1-ubyte.gz
# 113.5%
# Extracting mnist_train/MNIST/raw/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to mnist_train/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100.4%
# Extracting mnist_train/MNIST/raw/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to mnist_train/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 180.4%
# Extracting mnist_train/MNIST/raw/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
# %tensorboard --logdir runs # rode tensorboard --logdir=runs no terminal
# Out:
# Launching TensorBoard...
# invalid info file: '/tmp/.tensorboard-info/pid-31791.info'
# Traceback (most recent call last):
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXIiLCJsb2dzL2ZpdCJdLCJjb25maWd1cmVfa3dhcmdzIjp7fSwid29ya2luZ19kaXJlY3RvcnkiOiIvaG9tZS9pc3JhZWwvRG9jdW1lbnRzL01lc3RyYWRvL2lhMzUzL0VGQzIifQ==', 'db': '', 'logdir': 'logs/fit', 'path_prefix': '', 'pid': 31791, 'port': 6006, 'start_time': 1557582391, 'version': '1.14.0a20190301'}
# invalid info file: '/tmp/.tensorboard-info/pid-15912.info'
# Traceback (most recent call last):
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXIiLCJ7TE9HX0RJUn0iXSwiY29uZmlndXJlX2t3YXJncyI6e30sIndvcmtpbmdfZGlyZWN0b3J5IjoiL2hvbWUvaXNyYWVsL0RvY3VtZW50cy9NZXN0cmFkby9pYTM1My9FRkMyIn0=', 'db': '', 'logdir': '{LOG_DIR}', 'path_prefix': '', 'pid': 15912, 'port': 6011, 'start_time': 1557602636, 'version': '1.14.0a20190301'}
# invalid info file: '/tmp/.tensorboard-info/pid-5919.info'
# Traceback (most recent call last):
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXIiLCJsb2dzL2hwYXJhbV90dW5pbmciXSwiY29uZmlndXJlX2t3YXJncyI6e30sIndvcmtpbmdfZGlyZWN0b3J5IjoiL2hvbWUvaXNyYWVsL0RvY3VtZW50cy9NZXN0cmFkby9pYTM1My9FRkMyIn0=', 'db': '', 'logdir': 'logs/hparam_tuning', 'path_prefix': '', 'pid': 5919, 'port': 6007, 'start_time': 1557592160, 'version': '1.14.0a20190301'}
# invalid info file: '/tmp/.tensorboard-info/pid-6917.info'
# Traceback (most recent call last):
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXIiLCJsb2dzL2hwYXJhbXNfdHVuaW5nIl0sImNvbmZpZ3VyZV9rd2FyZ3MiOnt9LCJ3b3JraW5nX2RpcmVjdG9yeSI6Ii9ob21lL2lzcmFlbC9Eb2N1bWVudHMvTWVzdHJhZG8vaWEzNTMvRUZDMiJ9', 'db': '', 'logdir': 'logs/hparams_tuning', 'path_prefix': '', 'pid': 6917, 'port': 6008, 'start_time': 1557592320, 'version': '1.14.0a20190301'}
# invalid info file: '/tmp/.tensorboard-info/pid-15541.info'
# Traceback (most recent call last):
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXIiLCJsb2dzL21scC9ocGFyYW1zX3R1bmluZyJdLCJjb25maWd1cmVfa3dhcmdzIjp7fSwid29ya2luZ19kaXJlY3RvcnkiOiIvaG9tZS9pc3JhZWwvRG9jdW1lbnRzL01lc3RyYWRvL2lhMzUzL0VGQzIifQ==', 'db': '', 'logdir': 'logs/mlp/hparams_tuning', 'path_prefix': '', 'pid': 15541, 'port': 6009, 'start_time': 1557594645, 'version': '1.14.0a20190301'}
# invalid info file: '/tmp/.tensorboard-info/pid-17100.info'
# Traceback (most recent call last):
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXIiLCJsb2dzL21scC8iXSwiY29uZmlndXJlX2t3YXJncyI6e30sIndvcmtpbmdfZGlyZWN0b3J5IjoiL2hvbWUvaXNyYWVsL0RvY3VtZW50cy9NZXN0cmFkby9pYTM1My9FRkMyIn0=', 'db': '', 'logdir': 'logs/mlp/', 'path_prefix': '', 'pid': 17100, 'port': 6010, 'start_time': 1557595110, 'version': '1.14.0a20190301'}
# invalid info file: '/tmp/.tensorboard-info/pid-31791.info'
# Traceback (most recent call last):
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXIiLCJsb2dzL2ZpdCJdLCJjb25maWd1cmVfa3dhcmdzIjp7fSwid29ya2luZ19kaXJlY3RvcnkiOiIvaG9tZS9pc3JhZWwvRG9jdW1lbnRzL01lc3RyYWRvL2lhMzUzL0VGQzIifQ==', 'db': '', 'logdir': 'logs/fit', 'path_prefix': '', 'pid': 31791, 'port': 6006, 'start_time': 1557582391, 'version': '1.14.0a20190301'}
# invalid info file: '/tmp/.tensorboard-info/pid
 'version': '1.14.0a20190301'}
# invalid info file: '/tmp/.tensorboard-info/pid-15912.info'
# Traceback (most recent call last):
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXIiLCJ7TE9HX0RJUn0iXSwiY29uZmlndXJlX2t3YXJncyI6e30sIndvcmtpbmdfZGlyZWN0b3J5IjoiL2hvbWUvaXNyYWVsL0RvY3VtZW50cy9NZXN0cmFkby9pYTM1My9FRkMyIn0=', 'db': '', 'logdir': '{LOG_DIR}', 'path_prefix': '', 'pid': 15912, 'port': 6011, 'start_time': 1557602636, 'version': '1.14.0a20190301'}
# invalid info file: '/tmp/.tensorboard-info/pid-5919.info'
# Traceback (most recent call last):
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXIiLCJsb2dzL2hwYXJhbV90dW5pbmciXSwiY29uZmlndXJlX2t3YXJncyI6e30sIndvcmtpbmdfZGlyZWN0b3J5IjoiL2hvbWUvaXNyYWVsL0RvY3VtZW50cy9NZXN0cmFkby9pYTM1My9FRkMyIn0=', 'db': '', 'logdir': 'logs/hparam_tuning', 'path_prefix': '', 'pid': 5919, 'port': 6007, 'start_time': 1557592160, 'version': '1.14.0a20190301'}
# invalid info file: '/tmp/.tensorboard-info/pid-6917.info'
# Traceback (most recent call last):
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXIiLCJsb2dzL2hwYXJhbXNfdHVuaW5nIl0sImNvbmZpZ3VyZV9rd2FyZ3MiOnt9LCJ3b3JraW5nX2RpcmVjdG9yeSI6Ii9ob21lL2lzcmFlbC9Eb2N1bWVudHMvTWVzdHJhZG8vaWEzNTMvRUZDMiJ9', 'db': '', 'logdir': 'logs/hparams_tuning', 'path_prefix': '', 'pid': 6917, 'port': 6008, 'start_time': 1557592320, 'version': '1.14.0a20190301'}
# invalid info file: '/tmp/.tensorboard-info/pid-15541.info'
# Traceback (most recent call last):
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXIiLCJsb2dzL21scC9ocGFyYW1zX3R1bmluZyJdLCJjb25maWd1cmVfa3dhcmdzIjp7fSwid29ya2luZ19kaXJlY3RvcnkiOiIvaG9tZS9pc3JhZWwvRG9jdW1lbnRzL01lc3RyYWRvL2lhMzUzL0VGQzIifQ==', 'db': '', 'logdir': 'logs/mlp/hparams_tuning', 'path_prefix': '', 'pid': 15541, 'port': 6009, 'start_time': 1557594645, 'version': '1.14.0a20190301'}
# invalid info file: '/tmp/.tensorboard-info/pid-17100.info'
# Traceback (most recent call last):
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 316, in get_all
#     info = _info_from_string(contents)
#   File "/home/israel/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py", line 155, in _info_from_string
#     raise ValueError("incompatible version: %r" % (json_value,))
# ValueError: incompatible version: {'cache_key': 'eyJhcmd1bWVudHMiOlsiLS1sb2dkaXIiLCJsb2dzL21scC8iXSwiY29uZmlndXJlX2t3YXJncyI6e30sIndvcmtpbmdfZGlyZWN0b3J5IjoiL2hvbWUvaXNyYWVsL0RvY3VtZW50cy9NZXN0cmFkby9pYTM1My9FRkMyIn0=', 'db': '', 'logdir': 'logs/mlp/', 'path_prefix': '', 'pid': 17100, 'port': 6010, 'start_time': 1557595110, 'version': '1.14.0a20190301'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8ee48cf0f6fd> in <module>
# ----> 1 get_ipython().run_line_magic('tensorboard', '--logdir runs')
#
# ~/miniconda3/envs/torchenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
#    2308             return result
#    2309
#
# ~/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/notebook.py in _start_magic(line)
#     113 def _start_magic(line):
#     114   """Implementation of the `%tensorboard` line magic."""
# --> 115   return start(line)
#     116
#     117
#
# ~/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/notebook.py in start(args_string)
#     148
#     149   parsed_args = shlex.split(args_string, comments=True, posix=True)
# --> 150   start_result = manager.start(parsed_args)
#     151
#     152   if isinstance(start_result, manager.StartLaunched):
#
# ~/miniconda3/envs/torchenv/lib/python3.7/site-packages/tensorboard/manager.py in start(arguments, timeout)
#     411   end_time_seconds = start_time_seconds + timeout.total_seconds()
#     412   while time.time() < end_time_seconds:
# --> 413     time.sleep(poll_interval_seconds)
#     414     subprocess_result = p.poll()
#     415     if subprocess_result is not None:
#
# KeyboardInterrupt:
